# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/emlov2-session-03-saitej123

# %%
# !pip install -r /content/drive/MyDrive/emlov2-session-03-saitej123/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 701 kB 20.0 MB/s
# ...
#      |████████████████████████████████| 419 kB 70.7 MB/s
# ...
#      |████████████████████████████████| 509 kB 69.3 MB/s
# ...
#      |████████████████████████████████| 151 kB 71.1 MB/s
# ...
#      |████████████████████████████████| 199 kB 67.5 MB/s
# ...
#      |████████████████████████████████| 235 kB 66.8 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 51.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 10.2 MB/s
# ...
#      |████████████████████████████████| 117 kB 71.4 MB/s
# ...
#      |████████████████████████████████| 308 kB 67.7 MB/s
# ...
#      |████████████████████████████████| 81 kB 12.2 MB/s
# ...
#      |████████████████████████████████| 209 kB 73.9 MB/s
# ...
#      |████████████████████████████████| 98 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 59.8 MB/s
# ...
#      |████████████████████████████████| 468 kB 52.6 MB/s
# ...

# %%
! python3 /content/drive/MyDrive/emlov2-session-03-saitej123/src/train.py -m hparams_search=cifar10_optuna experiment=cifar
# Out:
# Streaming output truncated to the last 5000 lines.
#                                      0:00:40                   0
#                                                                train/loss_step:
#                                                                1.995
#                                                                train/acc_step:
# Epoch 0    ━━━━━╺━━━━━━━━━━ 493/1564 0:00:19 •       26.90it/s loss: 2.08 v_num:
#                                      0:00:40                   0
#                                                                train/loss_step:
#                                                                1.995
#                                                                train/acc_step:
# Epoch 0    ━━━━━╺━━━━━━━━━━ 493/1564 0:00:19 •       26.90it/s loss: 2.09 v_num:
#                                      0:00:40                   0
#                                                                train/loss_step:
# ...

# %%
import torch
torch.cuda.empty_cache()
